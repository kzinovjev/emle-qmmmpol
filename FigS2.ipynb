# %%
from itertools import product
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.transforms as mtransforms
from matplotlib.lines import Line2D

plt.rc('figure', facecolor='w')

# %%
def read_sd(filename):
    return np.loadtxt(filename).T

def plot_sd_single(ax, filename):
    x, y = read_sd(filename)
    ax.plot(x, y, color='#1f77b4')

# %%
filenames = {
    'La': [
        'wB97X/wB97X_gas_La_SD.dat',
        'wB97X/MM_gas_La_SD.dat',
        'wB97X/ANI-2x_gas_La_SD.dat',
        'wB97X/wB97X_ElEmb_La_SD.dat',
        'wB97X/MM_MM_La_SD.dat',
        'wB97X/ANI-2x_EMLE_La_SD.dat',
        'wB97X/ANI-2x_EMLE-NoPol_La_SD.dat',
        'wB97X/ANI-2x_EMLE-Mech_La_SD.dat',
        'wB97X/ANI-2x_MM_La_SD.dat',
    ],
    'Lb': [
        'wB97X/wB97X_gas_Lb_SD.dat',
        'wB97X/MM_gas_Lb_SD.dat',
        'wB97X/ANI-2x_gas_Lb_SD.dat',
        'wB97X/wB97X_ElEmb_Lb_SD.dat',
        'wB97X/MM_MM_Lb_SD.dat',
        'wB97X/ANI-2x_EMLE_Lb_SD.dat',
        'wB97X/ANI-2x_EMLE-NoPol_Lb_SD.dat',
        'wB97X/ANI-2x_EMLE-Mech_Lb_SD.dat',
        'wB97X/ANI-2x_MM_Lb_SD.dat',
    ]
}

systems = ['wB97X (gas)', 'MM (gas)', 'ANI-2x (gas)', 
           'wB97X/MM', 'MM', 'ANI-2x(EMLE)/MM', 
           'ANI-2x(EMLE-NoPol)/MM', 'ANI-2x(EMLE-Mech)/MM', 'ANI-2x(MM)/MM']

# %%
fig, axs = plt.subplots(3, 3, figsize=(14, 6), sharex=True)
fig.subplots_adjust(hspace=0.5)

gas_range = (0, 12000)
solv_range = (0, 50000)
ranges = [gas_range] * 3 + [solv_range] * 6

gas_ticks = np.arange(0, 13000, 2000)
solv_ticks = np.arange(0, 51000, 10000)
yticks = [gas_ticks] * 3 + [solv_ticks] * 6

for i, (system, filename, ax) in enumerate(zip(systems, filenames['La'], axs.T.flatten())):
    plot_sd_single(ax, filename)
    ax.patch.set_alpha(0.)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.set_ylim(*ranges[i])
    ax.set_yticks(yticks[i])
    for ytick in yticks[i]:
        ax.axhline(ytick, linewidth=0.5, color='lightgrey', zorder=0)
    if i in [2, 5, 8]:
        ax.set_xlabel('$\hbar \omega$ (cm$^{-1}$)')
    ax.set_title(system)
    
fig.text(0.06, 0.5, 'wB97X La Spectral Density (cm$^{-1}$)', va='center', rotation='vertical', fontsize='large')
fig.savefig('FigS2_top.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
fig, axs = plt.subplots(3, 3, figsize=(14, 6), sharex=True)
fig.subplots_adjust(hspace=0.5)

gas_range = (0, 5000)
solv_range = (0, 20000)
ranges = [gas_range] * 3 + [solv_range] * 6

gas_ticks = np.arange(0, 6000, 1000)
solv_ticks = np.arange(0, 21000, 4000)
yticks = [gas_ticks] * 3 + [solv_ticks] * 6

for i, (system, filename, ax) in enumerate(zip(systems, filenames['Lb'], axs.T.flatten())):
    plot_sd_single(ax, filename)
    ax.patch.set_alpha(0.)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.set_ylim(*ranges[i])
    ax.set_yticks(yticks[i])
    for ytick in yticks[i]:
        ax.axhline(ytick, linewidth=0.5, color='lightgrey', zorder=0)
    if i in [2, 5, 8]:
        ax.set_xlabel('$\hbar \omega$ (cm$^{-1}$)')
    ax.set_title(system)
    
fig.text(0.06, 0.5, 'wB97X Lb Spectral Density (cm$^{-1}$)', va='center', rotation='vertical', fontsize='large')
fig.savefig('FigS2_bottom.png', dpi=300, bbox_inches='tight')
plt.show()
